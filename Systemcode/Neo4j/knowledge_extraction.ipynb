# %% [markdown]
# # Knowledge Extraction Using NER Relationships

# %%
#!pip install transformers

# %%
#!git clone https://github.com/thunlp/OpenNRE.git

# %%
#!pip install -r OpenNRE/requirements.txt

# %%
#!python OpenNRE/setup.py install

# %%
#!pip install neo4j

# %%
from neo4j import GraphDatabase
from neo4j.exceptions import ServiceUnavailable
import json

# Initialize the graph DB and delete all the nodes and relationships
graph = GraphDatabase.driver(
    "neo4j+s://c22b0b3c.databases.neo4j.io:7687",
    auth=("neo4j", "akterzObCsJTwulDEG7AFlCkDcMyGC7RblEnmXbg7aE")
)

# %%
query = (
        "MATCH (all_nodes)"
        "OPTIONAL MATCH (all_nodes)-[all_rels]->()"
        "DELETE all_nodes, all_rels"
    )
with graph.session() as session:
    result = session.run(query)

# %%
import transformers
import OpenNRE.opennre as opennre

model = opennre.get_model('wiki80_bert_softmax')
# Out:
# 2024-04-27 21:09:14.576491: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-27 21:09:48,387 - root - INFO - Loading BERT pre-trained checkpoint.
# Some weights of the model checkpoint at /Users/sususan/.opennre/pretrain/bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pandas as pd
FAQ = pd.read_csv("./corpus/DBS FAQ.csv")
FAQ.head()
# Out:
#    Id     Section                                    SubSection  \
# 0   1  Bank Cards  Applying for a DBS Debit Card or Credit Card
# 1   2  Bank Cards  Applying for a DBS Debit Card or Credit Card
# 2   3  Bank Cards  Applying for a DBS Debit Card or Credit Card
# 3   4  Bank Cards  Applying for a DBS Debit Card or Credit Card
# 4   5  Bank Cards  Applying for a DBS Debit Card or Credit Card
#
#                    Label                             Question  \
# 0    eligible_debit_card      Am I eligible for a debit card?
# 1   eligible_credit_card     Am I eligible for a credit card?
# 2             apply_card             What do I need to apply?
# 3    apply_card_duration               How long does it take?
# 4  apply_card_turned dow  Why was my application turned down?
#
#                                               Answer
# 0  You must be at least 16 years old and have a P...
# 1  If you're Singaporean or have permanent reside...
# 2  The type of document you’ll need varies. Click...
# 3  Please allow 7 working days for processing. Ap...
# 4  All applications go through an approval proces...

# %% [markdown]
# # Create Constraint

# %%
with graph.session() as session:
    result = session.run('CREATE CONSTRAINT IF NOT EXISTS FOR (q:Question) REQUIRE q.Question IS UNIQUE;')

with graph.session() as session:
    result = session.run('CREATE CONSTRAINT IF NOT EXISTS FOR (a:Answer) REQUIRE a.Answer IS UNIQUE;')

with graph.session() as session:
    result = session.run('CREATE CONSTRAINT IF NOT EXISTS FOR (f:FAQ) REQUIRE f.Id IS UNIQUE;')

with graph.session() as session:
    result = session.run('CREATE CONSTRAINT IF NOT EXISTS FOR (s:Section) REQUIRE s.Section IS UNIQUE;')

with graph.session() as session:
    result = session.run('CREATE CONSTRAINT IF NOT EXISTS FOR (ss:SubSection) REQUIRE ss.SubSection IS UNIQUE;')

with graph.session() as session:
    result = session.run('CREATE TEXT INDEX question IF NOT EXISTS FOR (f:FAQ) ON f.Question;')

# %% [markdown]
# # Create Relationship

# %%
FAQ_import_query = """
UNWIND $data AS row
MERGE (f:FAQ {Id: row.Id})
MERGE (q:Question {Label: row.Question}) - [:PART_OF]->(f)
MERGE (a:Answer {Label: row.Answer}) - [:PART_OF]->(f)
SET f += apoc.map.clean(row, ["Id", "Section", "SubSection"], [])
WITH f,a,q,row.Section AS Section, row.SubSection AS SubSection, row.Question AS Question, row.Answer AS Answer
MERGE (s:Section {Label: Section})
MERGE (ss:SubSection {Label: SubSection})
MERGE (ss)-[:SUBSECTION_OF]->(s)
MERGE (f)-[:HAS_SUBSECTION]->(ss)
MERGE (q)-[:QUESTION_OF]->(a)
MERGE (a)-[:ANSWER_OF]->(q)
"""
with graph.session() as session:
    result = session.run(FAQ_import_query, {"data": FAQ.to_dict("records")})

# %% [markdown]
# # Knowledge Extraction

# %%
import networkx as nx
import matplotlib.pyplot as plt
import en_core_web_sm
import en_core_web_lg

#nlp = en_core_web_sm.load()
nlp = en_core_web_lg.load()

def knowledgeExtraction(questions,answers, FAQIDs):
   
    exist_ent = {}
    exist_relationship = []
    
    for i in range(0, len(answers)):
        question = questions[i]
        answer = answers[i]
        doc = nlp(answer)
        names_of_entities = []
        entities = []
        
        for ent in doc.ents:
            if ent.text not in names_of_entities:
                names_of_entities.append(ent.text)
                entities.append(ent)
    
        for ent in entities:
            if exist_ent.get(ent.text) is None:
                exist_ent[ent.text] = ent.text
                query = (
                "MATCH (FAQ:FAQ {Id: $FAQ_Id})"
                #"CREATE (node:Entity {name: $name, type: $type})- [:MENTIONS] -> (FAQ)"
                "MERGE (node: Entity {name: $name, type: $type}) - [:MENTIONS] -> (FAQ)" # Create Node Entity
                "RETURN node"
                )
                with graph.session() as session:
                    result = session.run(query, name=ent.text, type = ent.label_,FAQ_Id = FAQIDs[i])
                print("create new node with name as {0} and with type as {1} and sentiment with {2}".format(ent.text, ent.label_, ent.sentiment))
    
        for i in range(len(entities)):
            for j in range(i + 1, len(entities)):
                text_i = entities[i].text
                text_j = entities[j].text
                loc_h = answer.find(text_i)
                loc_t = answer.find(text_j)
                result = model.infer({'text': answer, 'h': {'pos': (loc_h, loc_h + len(text_i))},
                                    't': {'pos': (loc_t, loc_t + len(text_j))}})
                (rel, confidence) = result[0].replace(' ', '_'), result[1]
    
                record = (text_i, text_j, rel, confidence)
    
                result_rev = model.infer({'text': answer, 'h': {'pos': (loc_t, loc_t + len(text_j))},
                                    't': {'pos': (loc_h, loc_h + len(text_i))}})
                (rel_rev, confidence) = result_rev[0].replace(' ', '_'), result_rev[1]
    
                record_rev = (text_j, text_i, rel_rev, confidence)
                if record not in exist_relationship:
                    exist_relationship.append(record)
                    if record[3] > 0.8:
                        query = (
                            "MATCH (n1 {name: $name1})"
                            "MATCH (n2 {name: $name2})"
                            "MERGE (n1) - [r:"+record[2]+"] -> (n2)"
                            "RETURN n1, n2, r"
                        )
                        #print(query, name1=exist_ent[text_i], name2=exist_ent[text_j])
                        with graph.session() as session:
                            result = session.run(query, name1=exist_ent[text_i], name2=exist_ent[text_j])
                        print("create new relationship {0} - {1} -> {2} with confidence of {3}".format(record[0], record[2], record[1], record[3]))
    
                if record_rev not in exist_relationship:
                    exist_relationship.append(record_rev)
                    if record_rev[3] > 0.8:
                        query = (
                            "MATCH (n1 {name: $name1})"
                            "MATCH (n2 {name: $name2})"
                            "MERGE (n1) - [r:"+record_rev[2]+"] -> (n2)"   
                            "RETURN n1, n2, r"
                        )
                        print(exist_ent[text_j].replace(' ' , '_') + ' ' + exist_ent[text_i] + ' ' + record_rev[2])
                        with graph.session() as session:
                            result = session.run(query, name1=exist_ent[text_j], name2=exist_ent[text_i])
                        print("create new relationship {0} - {1} -> {2} with confidence of {3}".format(record_rev[0], record_rev[2], record_rev[1], record_rev[3]))

# %%
questions = []
answers = []
FAQIDs = []
for i in range(len(FAQ)):
    questions.append(FAQ.loc[i].Question)
    answers.append(FAQ.loc[i].Answer)
    FAQIDs.append(FAQ.loc[i].Id)

# %%
knowledgeExtraction(questions,answers,FAQIDs)
# Out:
# create new node with name as at least 16 years old and with type as DATE and sentiment with 0.0
# create new node with name as DBS Savings Plus Account and with type as ORG and sentiment with 0.0
# create new node with name as DBS Autosave Account and with type as ORG and sentiment with 0.0
# create new node with name as DBS Current Account and with type as ORG and sentiment with 0.0
# create new node with name as href="https://www.dbs.com.sg and with type as ORG and sentiment with 0.0
# create new node with name as at least 6 months and with type as DATE and sentiment with 0.0
# create new relationship DBS Savings Plus Account - followed_by -> DBS Autosave Account with confidence of 0.9901670217514038
# DBS_Autosave_Account DBS Savings Plus Account followed_by
# create new relationship DBS Autosave Account - followed_by -> DBS Savings Plus Account with confidence of 0.9828715324401855
# create new relationship DBS Savings Plus Account - followed_by -> DBS Current Account with confidence of 0.9697880148887634
# DBS_Current_Account DBS Savings Plus Account followed_by
# create new relationship DBS Current Account - followed_by -> DBS Savings Plus Account with confidence of 0.9342776536941528
# create new relationship DBS Autosave Account - followed_by -> DBS Current Account with confidence of 0.9852199554443359
# DBS_Current_Account DBS Autosave Account followed_by
# create new relationship DBS Current Account - followed_by -> DBS Autosave Account with confidence of 0.9752067923545837
# create new relationship DBS Autosave Account - followed_by -> href="https://www.dbs.com.sg with confidence of 0.8887360692024231
# href="https://www.dbs.com.sg DBS Autosave Account followed_by
# create new relationship href="https://www.dbs.com.sg - followed_by -> DBS Autosave Account with confidence of 0.893096387386322
# create new relationship DBS Autosave Account - followed_by -> at least 6 months with confidence of 0.9528752565383911
# at_least_6_months DBS Autosave Account followed_by
# create new relationship at least 6 months - followed_by -> DBS Autosave Account with confidence of 0.9555076360702515
# create new node with name as Singaporean and with type as NORP and sentiment with 0.0
# create new node with name as 21 years of age and with type as DATE and sentiment with 0.0
# create new node with name as S$30,000 and with type as LOC and sentiment with 0.0
# create new node with name as Platinum and with type as ORG and sentiment with 0.0
# create new node with name as a least S$45,000 and with type as MONEY and sentiment with 0.0
# create new node with name as a year and with type as DATE and sentiment with 0.0
# create new relationship Singaporean - part_of -> 21 years of age with confidence of 0.8797944784164429
# 21_years_of_age Singaporean part_of
# create new relationship 21 years of age - part_of -> Singaporean with confidence of 0.9257203936576843
# create new relationship Singaporean - part_of -> href="https://www.dbs.com.sg with confidence of 0.8138021230697632
# href="https://www.dbs.com.sg Singaporean part_of
# create new relationship href="https://www.dbs.com.sg - part_of -> Singaporean with confidence of 0.8959383368492126
# create new relationship Singaporean - part_of -> S$30,000 with confidence of 0.8951045274734497
# S$30,000 Singaporean part_of
# create new relationship S$30,000 - part_of -> Singaporean with confidence of 0.8982707262039185
# create new relationship Singaporean - part_of -> Platinum with confidence of 0.8691118955612183
# Platinum Singaporean part_of
# create new relationship Platinum - part_of -> Singaporean with confidence of 0.9103177189826965
# create new relationship Singaporean - part_of -> a least S$45,000 with confidence of 0.8691118955612183
# a_least_S$45,000 Singaporean part_of
# create new relationship a least S$45,000 - part_of -> Singaporean with confidence of 0.9103177189826965
# create new relationship Singaporean - part_of -> a year with confidence of 0.8691118955612183
# a_year Singaporean part_of
# create new relationship a year - part_of -> Singaporean with confidence of 0.9103177189826965
# create new relationship href="https://www.dbs.com.sg - main_subject -> Platinum with confidence of 0.8060263991355896
# create new relationship href="https://www.dbs.com.sg - main_subject -> a least S$45,000 with confidence of 0.8060263991355896
# create new relationship href="https://www.dbs.com.sg - main_subject -> a year with confidence of 0.8060263991355896
# create new node with name as 7 working days and with type as DATE and sentiment with 0.0
# create new node with name as account</a and with type as PERSON and sentiment with 0.0
# create new node with name as >Debit and with type as WORK_OF_ART and sentiment with 0.0
# create new node with name as Credit Card and with type as ORG and sentiment with 0.0
# create new node with name as https://abs.org.sg and with type as ORG and sentiment with 0.0
# create new relationship 7 working days - has_part -> href="https://www.dbs.com.sg with confidence of 0.9762555956840515
# href="https://www.dbs.com.sg 7 working days has_part
# create new relationship href="https://www.dbs.com.sg - has_part -> 7 working days with confidence of 0.9807028770446777
# create new relationship 7 working days - has_part -> >Debit with confidence of 0.9772714376449585
# >Debit 7 working days has_part
# create new relationship >Debit - has_part -> 7 working days with confidence of 0.9797724485397339
# create new relationship 7 working days - has_part -> Credit Card with confidence of 0.9772714376449585
# Credit_Card 7 working days has_part
# create new relationship Credit Card - has_part -> 7 working days with confidence of 0.9797724485397339
# create new relationship 7 working days - has_part -> https://abs.org.sg with confidence of 0.9772714376449585
# https://abs.org.sg 7 working days has_part
# create new relationship https://abs.org.sg - has_part -> 7 working days with confidence of 0.9797724485397339
# create new node with name as DBS Rewards and with type as ORG and sentiment with 0.0
# create new node with name as DBS Credit Card and with type as ORG and sentiment with 0.0
# create new node with name as DBS Points and with type as ORG and sentiment with 0.0
# create new relationship DBS Rewards - has_part -> DBS Points with confidence of 0.8254706859588623
# DBS_Points DBS Rewards has_part
# create new relationship DBS Points - has_part -> DBS Rewards with confidence of 0.8256783485412598
# create new node with name as DBS Points Redemption Programme and with type as ORG and sentiment with 0.0
# create new node with name as Programme and with type as ORG and sentiment with 0.0
# create new node with name as MasterCard Corporate/ Executive and with type as ORG and sentiment with 0.0
# create new node with name as Visa Corporate/ Business and with type as ORG and sentiment with 0.0
# create new node with name as DBS Purchasing Card
# Country Club Corporate Card and with type as PRODUCT and sentiment with 0.0
# create new node with name as DBS Esso Card and with type as ORG and sentiment with 0.0
# create new node with name as DBS Credit/Debit Card
# POSB Credit Card and with type as ORG and sentiment with 0.0
# create new relationship DBS Points Redemption Programme - instance_of -> Programme with confidence of 0.9372410178184509
# create new relationship DBS Points Redemption Programme - main_subject -> MasterCard Corporate/ Executive with confidence of 0.9070440530776978
# MasterCard_Corporate/_Executive DBS Points Redemption Programme main_subject
# create new relationship MasterCard Corporate/ Executive - main_subject -> DBS Points Redemption Programme with confidence of 0.9378654360771179
# DBS_Purchasing_Card
# Country_Club_Corporate_Card DBS Points Redemption Programme main_subject
# create new relationship DBS Purchasing Card
# Country Club Corporate Card - main_subject -> DBS Points Redemption Programme with confidence of 0.9254200458526611
# create new relationship DBS Points Redemption Programme - main_subject -> DBS Esso Card with confidence of 0.9855319857597351
# DBS_Esso_Card DBS Points Redemption Programme main_subject
# create new relationship DBS Esso Card - main_subject -> DBS Points Redemption Programme with confidence of 0.9882778525352478
# create new relationship DBS Points Redemption Programme - main_subject -> DBS Credit/Debit Card
# POSB Credit Card with confidence of 0.988377034664154
# DBS_Credit/Debit_Card
# POSB_Credit_Card DBS Points Redemption Programme main_subject
# create new relationship DBS Credit/Debit Card
# POSB Credit Card - main_subject -> DBS Points Redemption Programme with confidence of 0.9906170964241028
# create new relationship Programme - main_subject -> MasterCard Corporate/ Executive with confidence of 0.8769432902336121
# create new relationship Programme - main_subject -> DBS Purchasing Card
# Country Club Corporate Card with confidence of 0.819908618927002
# create new relationship Programme - main_subject -> DBS Esso Card with confidence of 0.9066499471664429
# create new relationship Programme - main_subject -> DBS Credit/Debit Card
# POSB Credit Card with confidence of 0.9369453191757202
# create new relationship MasterCard Corporate/ Executive - followed_by -> Visa Corporate/ Business with confidence of 0.893593966960907
# create new relationship MasterCard Corporate/ Executive - has_part -> DBS Purchasing Card
# Country Club Corporate Card with confidence of 0.8935515880584717
# DBS_Purchasing_Card
# Country_Club_Corporate_Card MasterCard Corporate/ Executive has_part
# create new relationship DBS Purchasing Card
# Country Club Corporate Card - has_part -> MasterCard Corporate/ Executive with confidence of 0.9379759430885315
# DBS_Esso_Card MasterCard Corporate/ Executive has_part
# create new relationship DBS Esso Card - has_part -> MasterCard Corporate/ Executive with confidence of 0.8021602034568787
# create new relationship MasterCard Corporate/ Executive - has_part -> DBS Credit/Debit Card
# POSB Credit Card with confidence of 0.9722890853881836
# DBS_Credit/Debit_Card
# POSB_Credit_Card MasterCard Corporate/ Executive has_part
# create new relationship DBS Credit/Debit Card
# POSB Credit Card - has_part -> MasterCard Corporate/ Executive with confidence of 0.9815897345542908
# create new node with name as 1 and with type as CARDINAL and sentiment with 0.0
# create new node with name as DBS Point and with type as LOC and sentiment with 0.0
# DBS_Point 1 has_part
# create new relationship DBS Point - has_part -> 1 with confidence of 0.8132795691490173
# create new node with name as 3 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 5 and with type as CARDINAL and sentiment with 0.0
# create new node with name as Singapore and with type as GPE and sentiment with 0.0
# create new relationship 3 - followed_by -> DBS Points with confidence of 0.860730767250061
# DBS_Points 3 followed_by
# create new relationship DBS Points - followed_by -> 3 with confidence of 0.8954610824584961
# Singapore 3 has_part
# create new relationship Singapore - has_part -> 3 with confidence of 0.8134176135063171
# create new node with name as Bill and with type as PERSON and sentiment with 0.0
# create new node with name as AXS and with type as ORG and sentiment with 0.0
# create new node with name as SAM and with type as ORG and sentiment with 0.0
# create new node with name as EZ-Link and with type as ORG and sentiment with 0.0
# create new node with name as GrabPay and with type as ORG and sentiment with 0.0
# create new node with name as FlashPay and with type as ORG and sentiment with 0.0
# create new node with name as Razer Pay and with type as ORG and sentiment with 0.0
# create new node with name as ShopeePay and with type as ORG and sentiment with 0.0
# create new node with name as Singtel Dash and with type as ORG and sentiment with 0.0
# create new node with name as Transit Link and with type as ORG and sentiment with 0.0
# create new node with name as annual and with type as DATE and sentiment with 0.0
# create new node with name as DBS and with type as ORG and sentiment with 0.0
# create new relationship DBS Points - part_of -> Bill with confidence of 0.960317850112915
# AXS DBS Points followed_by
# create new relationship AXS - followed_by -> DBS Points with confidence of 0.8749830722808838
# create new relationship DBS Points - followed_by -> SAM with confidence of 0.9634966254234314
# SAM DBS Points followed_by
# create new relationship SAM - followed_by -> DBS Points with confidence of 0.9681462645530701
# create new relationship DBS Points - followed_by -> EZ-Link with confidence of 0.932285726070404
# EZ-Link DBS Points followed_by
# create new relationship EZ-Link - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> GrabPay with confidence of 0.932285726070404
# GrabPay DBS Points followed_by
# create new relationship GrabPay - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> FlashPay with confidence of 0.932285726070404
# FlashPay DBS Points followed_by
# create new relationship FlashPay - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> Razer Pay with confidence of 0.932285726070404
# Razer_Pay DBS Points followed_by
# create new relationship Razer Pay - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> ShopeePay with confidence of 0.932285726070404
# ShopeePay DBS Points followed_by
# create new relationship ShopeePay - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> Singtel Dash with confidence of 0.932285726070404
# Singtel_Dash DBS Points followed_by
# create new relationship Singtel Dash - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> Transit Link with confidence of 0.932285726070404
# Transit_Link DBS Points followed_by
# create new relationship Transit Link - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship DBS Points - followed_by -> annual with confidence of 0.932285726070404
# annual DBS Points followed_by
# create new relationship annual - followed_by -> DBS Points with confidence of 0.9263111352920532
# create new relationship Bill - main_subject -> EZ-Link with confidence of 0.8909081220626831
# EZ-Link Bill main_subject
# create new relationship EZ-Link - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> GrabPay with confidence of 0.8909081220626831
# GrabPay Bill main_subject
# create new relationship GrabPay - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> FlashPay with confidence of 0.8909081220626831
# FlashPay Bill main_subject
# create new relationship FlashPay - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> Razer Pay with confidence of 0.8909081220626831
# Razer_Pay Bill main_subject
# create new relationship Razer Pay - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> ShopeePay with confidence of 0.8909081220626831
# ShopeePay Bill main_subject
# create new relationship ShopeePay - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> Singtel Dash with confidence of 0.8909081220626831
# Singtel_Dash Bill main_subject
# create new relationship Singtel Dash - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> Transit Link with confidence of 0.8909081220626831
# Transit_Link Bill main_subject
# create new relationship Transit Link - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship Bill - main_subject -> annual with confidence of 0.8909081220626831
# annual Bill main_subject
# create new relationship annual - main_subject -> Bill with confidence of 0.9790481328964233
# create new relationship AXS - followed_by -> SAM with confidence of 0.9554804563522339
# SAM AXS followed_by
# create new relationship SAM - followed_by -> AXS with confidence of 0.8533704876899719
# create new relationship SAM - followed_by -> DBS with confidence of 0.930884063243866
# DBS SAM followed_by
# create new relationship DBS - followed_by -> SAM with confidence of 0.9429145455360413
# create new relationship EZ-Link - followed_by -> DBS with confidence of 0.9219642877578735
# DBS EZ-Link followed_by
# create new relationship DBS - followed_by -> EZ-Link with confidence of 0.9385015964508057
# create new relationship GrabPay - followed_by -> DBS with confidence of 0.9219642877578735
# DBS GrabPay followed_by
# create new relationship DBS - followed_by -> GrabPay with confidence of 0.9385015964508057
# create new relationship FlashPay - followed_by -> DBS with confidence of 0.9219642877578735
# DBS FlashPay followed_by
# create new relationship DBS - followed_by -> FlashPay with confidence of 0.9385015964508057
# create new relationship Razer Pay - followed_by -> DBS with confidence of 0.9219642877578735
# DBS Razer Pay followed_by
# create new relationship DBS - followed_by -> Razer Pay with confidence of 0.9385015964508057
# create new relationship ShopeePay - followed_by -> DBS with confidence of 0.9219642877578735
# DBS ShopeePay followed_by
# create new relationship DBS - followed_by -> ShopeePay with confidence of 0.9385015964508057
# create new relationship Singtel Dash - followed_by -> DBS with confidence of 0.9219642877578735
# DBS Singtel Dash followed_by
# create new relationship DBS - followed_by -> Singtel Dash with confidence of 0.9385015964508057
# create new relationship Transit Link - followed_by -> DBS with confidence of 0.9219642877578735
# DBS Transit Link followed_by
# create new relationship DBS - followed_by -> Transit Link with confidence of 0.9385015964508057
# create new relationship annual - followed_by -> DBS with confidence of 0.9219642877578735
# DBS annual followed_by
# create new relationship DBS - followed_by -> annual with confidence of 0.9385015964508057
# create new node with name as DBS Points for Rewards and with type as ORG and sentiment with 0.0
# create new node with name as the Rewards Vouchers and with type as ORG and sentiment with 0.0
# create new node with name as monthly and with type as DATE and sentiment with 0.0
# create new node with name as DBS PayLah and with type as ORG and sentiment with 0.0
# create new relationship monthly - part_of -> Credit Card with confidence of 0.9445096850395203
# Credit_Card monthly part_of
# create new relationship Credit Card - part_of -> monthly with confidence of 0.9218611121177673
# create new node with name as a few days and with type as DATE and sentiment with 0.0
# create new node with name as 1 month and with type as DATE and sentiment with 0.0
# create new node with name as Annual and with type as DATE and sentiment with 0.0
# create new node with name as the following month's and with type as DATE and sentiment with 0.0
# create new relationship 1 month - part_of -> Credit Card with confidence of 0.8651261329650879
# create new relationship 1 month - followed_by -> the following month's with confidence of 0.9379753470420837
# the_following_month's 1 month followed_by
# create new relationship the following month's - followed_by -> 1 month with confidence of 0.8208729028701782
# create new relationship Annual - part_of -> Credit Card with confidence of 0.936951756477356
# Credit_Card Annual part_of
# create new relationship Credit Card - part_of -> Annual with confidence of 0.8984712362289429
# create new relationship Annual - followed_by -> the following month's with confidence of 0.8168022632598877
# create new relationship annual - part_of -> Credit Card with confidence of 0.974150538444519
# Credit_Card annual part_of
# create new relationship Credit Card - part_of -> annual with confidence of 0.963668167591095
# create new relationship annual - followed_by -> the following month's with confidence of 0.9342215657234192
# the_following_month's annual followed_by
# create new relationship the following month's - followed_by -> annual with confidence of 0.8812921047210693
# create new node with name as KrisFlyer and with type as ORG and sentiment with 0.0
# create new node with name as Qantas Points and with type as ORG and sentiment with 0.0
# create new node with name as 2 miles and with type as QUANTITY and sentiment with 0.0
# create new node with name as 5,000 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 10,000 miles and with type as QUANTITY and sentiment with 0.0
# create new node with name as Air Asia and with type as ORG and sentiment with 0.0
# create new node with name as 500 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 1,500 and with type as CARDINAL and sentiment with 0.0
# create new node with name as a S$27.25 administration and with type as GPE and sentiment with 0.0
# create new node with name as 31 Dec 2024 and with type as DATE and sentiment with 0.0
# create new node with name as noreferrer">https://rewards.dbs.com</a and with type as ORG and sentiment with 0.0
# create new node with name as approximately 1 - 2 weeks and with type as CARDINAL and sentiment with 0.0
# create new relationship KrisFlyer - followed_by -> 5,000 with confidence of 0.8390920758247375
# create new relationship KrisFlyer - followed_by -> 3 with confidence of 0.9228342771530151
# 3 KrisFlyer followed_by
# create new relationship 3 - followed_by -> KrisFlyer with confidence of 0.8478980660438538
# create new relationship Qantas Points - has_part -> 1 with confidence of 0.8222016096115112
# create new relationship Qantas Points - has_part -> Air Asia with confidence of 0.8108397126197815
# create new relationship Qantas Points - has_part -> DBS Point with confidence of 0.8807949423789978
# create new relationship Qantas Points - has_part -> 3 with confidence of 0.804230272769928
# create new relationship Qantas Points - has_part -> 500 with confidence of 0.8479778170585632
# create new relationship Qantas Points - part_of -> 1,500 with confidence of 0.9310262799263
# 1,500 Qantas Points part_of
# create new relationship 1,500 - part_of -> Qantas Points with confidence of 0.9699512720108032
# create new relationship Qantas Points - part_of -> a S$27.25 administration with confidence of 0.9310262799263
# a_S$27.25_administration Qantas Points part_of
# create new relationship a S$27.25 administration - part_of -> Qantas Points with confidence of 0.9699512720108032
# create new relationship Qantas Points - part_of -> 31 Dec 2024 with confidence of 0.9310262799263
# 31_Dec_2024 Qantas Points part_of
# create new relationship 31 Dec 2024 - part_of -> Qantas Points with confidence of 0.9699512720108032
# create new relationship Qantas Points - part_of -> noreferrer">https://rewards.dbs.com</a with confidence of 0.9310262799263
# noreferrer">https://rewards.dbs.com</a Qantas Points part_of
# create new relationship noreferrer">https://rewards.dbs.com</a - part_of -> Qantas Points with confidence of 0.9699512720108032
# create new relationship Qantas Points - part_of -> approximately 1 - 2 weeks with confidence of 0.9310262799263
# approximately_1_-_2_weeks Qantas Points part_of
# create new relationship approximately 1 - 2 weeks - part_of -> Qantas Points with confidence of 0.9699512720108032
# create new relationship 1 - followed_by -> 5,000 with confidence of 0.9845436215400696
# 5,000 1 followed_by
# create new relationship 5,000 - followed_by -> 1 with confidence of 0.9547110795974731
# create new relationship 1 - followed_by -> DBS Points with confidence of 0.8639518022537231
# create new relationship 1 - followed_by -> DBS Point with confidence of 0.8506357073783875
# create new relationship 1 - followed_by -> 3 with confidence of 0.9900804162025452
# 3 1 followed_by
# create new relationship 3 - followed_by -> 1 with confidence of 0.9889544248580933
# create new relationship 1 - followed_by -> 500 with confidence of 0.8745476603507996
# 500 1 followed_by
# create new relationship 500 - followed_by -> 1 with confidence of 0.8384647369384766
# create new relationship 5,000 - followed_by -> DBS Points with confidence of 0.9412329792976379
# DBS_Points 5,000 followed_by
# create new relationship DBS Points - followed_by -> 5,000 with confidence of 0.9191647171974182
# create new relationship 5,000 - followed_by -> 10,000 miles with confidence of 0.8876075744628906
# 10,000_miles 5,000 followed_by
# create new relationship 10,000 miles - followed_by -> 5,000 with confidence of 0.890712559223175
# DBS_Point 5,000 followed_by
# create new relationship DBS Point - followed_by -> 5,000 with confidence of 0.9292778372764587
# create new relationship 5,000 - followed_by -> 3 with confidence of 0.9849516749382019
# 3 5,000 followed_by
# create new relationship 3 - followed_by -> 5,000 with confidence of 0.9799267649650574
# create new relationship 5,000 - followed_by -> 500 with confidence of 0.9851539134979248
# 500 5,000 followed_by
# create new relationship 500 - followed_by -> 5,000 with confidence of 0.9765375852584839
# 1,500 5,000 followed_by
# create new relationship 1,500 - followed_by -> 5,000 with confidence of 0.8048588037490845
# a_S$27.25_administration 5,000 followed_by
# create new relationship a S$27.25 administration - followed_by -> 5,000 with confidence of 0.8048588037490845
# 31_Dec_2024 5,000 followed_by
# create new relationship 31 Dec 2024 - followed_by -> 5,000 with confidence of 0.8048588037490845
# noreferrer">https://rewards.dbs.com</a 5,000 followed_by
# create new relationship noreferrer">https://rewards.dbs.com</a - followed_by -> 5,000 with confidence of 0.8048588037490845
# approximately_1_-_2_weeks 5,000 followed_by
# create new relationship approximately 1 - 2 weeks - followed_by -> 5,000 with confidence of 0.8048588037490845
# create new relationship DBS Points - said_to_be_the_same_as -> 10,000 miles with confidence of 0.9956335425376892
# 10,000_miles DBS Points said_to_be_the_same_as
# create new relationship 10,000 miles - said_to_be_the_same_as -> DBS Points with confidence of 0.9853497743606567
# create new relationship DBS Points - followed_by -> DBS Point with confidence of 0.8428500890731812
# DBS_Point DBS Points followed_by
# create new relationship DBS Point - followed_by -> DBS Points with confidence of 0.9465136528015137
# create new relationship DBS Points - followed_by -> 3 with confidence of 0.9431597590446472
# 3 DBS Points followed_by
# create new relationship 3 - followed_by -> DBS Points with confidence of 0.958913266658783
# create new relationship 10,000 miles - has_part -> Air Asia with confidence of 0.8170901536941528
# DBS_Point 10,000 miles said_to_be_the_same_as
# create new relationship DBS Point - said_to_be_the_same_as -> 10,000 miles with confidence of 0.9004341959953308
# create new relationship 10,000 miles - has_part -> 500 with confidence of 0.8100469708442688
# 500 10,000 miles has_part
# create new relationship 500 - has_part -> 10,000 miles with confidence of 0.8547121286392212
# create new relationship 10,000 miles - has_part -> 1,500 with confidence of 0.9304569363594055
# 1,500 10,000 miles has_part
# create new relationship 1,500 - has_part -> 10,000 miles with confidence of 0.9261484146118164
# create new relationship 10,000 miles - has_part -> a S$27.25 administration with confidence of 0.9304569363594055
# a_S$27.25_administration 10,000 miles has_part
# create new relationship a S$27.25 administration - has_part -> 10,000 miles with confidence of 0.9261484146118164
# create new relationship 10,000 miles - has_part -> 31 Dec 2024 with confidence of 0.9304569363594055
# 31_Dec_2024 10,000 miles has_part
# create new relationship 31 Dec 2024 - has_part -> 10,000 miles with confidence of 0.9261484146118164
# create new relationship 10,000 miles - has_part -> noreferrer">https://rewards.dbs.com</a with confidence of 0.9304569363594055
# noreferrer">https://rewards.dbs.com</a 10,000 miles has_part
# create new relationship noreferrer">https://rewards.dbs.com</a - has_part -> 10,000 miles with confidence of 0.9261484146118164
# create new relationship 10,000 miles - has_part -> approximately 1 - 2 weeks with confidence of 0.9304569363594055
# approximately_1_-_2_weeks 10,000 miles has_part
# create new relationship approximately 1 - 2 weeks - has_part -> 10,000 miles with confidence of 0.9261484146118164
# create new relationship Air Asia - has_part -> DBS Point with confidence of 0.8611277341842651
# DBS_Point Air Asia has_part
# create new relationship DBS Point - has_part -> Air Asia with confidence of 0.8252712488174438
# create new relationship Air Asia - followed_by -> 3 with confidence of 0.9140831828117371
# 3 Air Asia followed_by
# create new relationship 3 - followed_by -> Air Asia with confidence of 0.9062797427177429
# create new relationship DBS Point - followed_by -> 3 with confidence of 0.9373305439949036
# 3 DBS Point followed_by
# create new relationship 3 - followed_by -> DBS Point with confidence of 0.9557698965072632
# create new relationship DBS Point - has_part -> 1,500 with confidence of 0.831183671951294
# 1,500 DBS Point has_part
# create new relationship 1,500 - has_part -> DBS Point with confidence of 0.8432498574256897
# create new relationship DBS Point - has_part -> a S$27.25 administration with confidence of 0.831183671951294
# a_S$27.25_administration DBS Point has_part
# create new relationship a S$27.25 administration - has_part -> DBS Point with confidence of 0.8432498574256897
# create new relationship DBS Point - has_part -> 31 Dec 2024 with confidence of 0.831183671951294
# 31_Dec_2024 DBS Point has_part
# create new relationship 31 Dec 2024 - has_part -> DBS Point with confidence of 0.8432498574256897
# create new relationship DBS Point - has_part -> noreferrer">https://rewards.dbs.com</a with confidence of 0.831183671951294
# noreferrer">https://rewards.dbs.com</a DBS Point has_part
# create new relationship noreferrer">https://rewards.dbs.com</a - has_part -> DBS Point with confidence of 0.8432498574256897
# create new relationship DBS Point - has_part -> approximately 1 - 2 weeks with confidence of 0.831183671951294
# approximately_1_-_2_weeks DBS Point has_part
# create new relationship approximately 1 - 2 weeks - has_part -> DBS Point with confidence of 0.8432498574256897
# create new relationship 3 - followed_by -> 500 with confidence of 0.9692606925964355
# 500 3 followed_by
# create new relationship 500 - followed_by -> 3 with confidence of 0.9693183302879333
# create new relationship 3 - followed_by -> 1,500 with confidence of 0.934023380279541
# 1,500 3 followed_by
# create new relationship 1,500 - followed_by -> 3 with confidence of 0.9617506861686707
# create new relationship 3 - followed_by -> a S$27.25 administration with confidence of 0.934023380279541
# a_S$27.25_administration 3 followed_by
# create new relationship a S$27.25 administration - followed_by -> 3 with confidence of 0.9617506861686707
# create new relationship 3 - followed_by -> 31 Dec 2024 with confidence of 0.934023380279541
# 31_Dec_2024 3 followed_by
# create new relationship 31 Dec 2024 - followed_by -> 3 with confidence of 0.9617506861686707
# create new relationship 3 - followed_by -> noreferrer">https://rewards.dbs.com</a with confidence of 0.934023380279541
# noreferrer">https://rewards.dbs.com</a 3 followed_by
# create new relationship noreferrer">https://rewards.dbs.com</a - followed_by -> 3 with confidence of 0.9617506861686707
# create new relationship 3 - followed_by -> approximately 1 - 2 weeks with confidence of 0.934023380279541
# approximately_1_-_2_weeks 3 followed_by
# create new relationship approximately 1 - 2 weeks - followed_by -> 3 with confidence of 0.9617506861686707
# create new node with name as PIN and with type as ORG and sentiment with 0.0
# create new node with name as Daily$ and with type as PRODUCT and sentiment with 0.0
# create new node with name as DBS/POSB and with type as ORG and sentiment with 0.0
# create new node with name as DBS Corporate Liability Card and with type as ORG and sentiment with 0.0
# create new node with name as DBS Saab Credit Card and with type as ORG and sentiment with 0.0
# create new node with name as DBS Takashimaya Card and with type as ORG and sentiment with 0.0
# create new node with name as DBS Credit/Debit Card and with type as ORG and sentiment with 0.0
# create new relationship DBS Saab Credit Card - instance_of -> DBS Credit/Debit Card with confidence of 0.9601203799247742
# DBS_Credit/Debit_Card DBS Saab Credit Card instance_of
# create new relationship DBS Credit/Debit Card - instance_of -> DBS Saab Credit Card with confidence of 0.9618926644325256
# create new relationship DBS Takashimaya Card - instance_of -> DBS Credit/Debit Card with confidence of 0.8073196411132812
# create new relationship DBS Esso Card - instance_of -> DBS Credit/Debit Card with confidence of 0.9617488384246826
# DBS_Credit/Debit_Card DBS Esso Card instance_of
# create new relationship DBS Credit/Debit Card - instance_of -> DBS Esso Card with confidence of 0.9107393622398376
# create new node with name as "My DBS Points Details and with type as WORK_OF_ART and sentiment with 0.0
# create new node with name as 24 hours and with type as TIME and sentiment with 0.0
# create new node with name as Next working day and with type as DATE and sentiment with 0.0
# create new node with name as AXS Stations and with type as ORG and sentiment with 0.0
# create new node with name as InterBank and with type as ORG and sentiment with 0.0
# create new node with name as 3rd working day and with type as DATE and sentiment with 0.0
# create new relationship DBS/POSB - subsidiary -> InterBank with confidence of 0.9476721286773682
# InterBank DBS/POSB subsidiary
# create new relationship InterBank - subsidiary -> DBS/POSB with confidence of 0.9528747200965881
# create new node with name as 25 and with type as CARDINAL and sentiment with 0.0
# create new node with name as daily and with type as DATE and sentiment with 0.0
# create new node with name as S$2.50 and with type as GPE and sentiment with 0.0
# create new relationship 25 - followed_by -> daily with confidence of 0.8133096098899841
# daily 25 followed_by
# create new relationship daily - followed_by -> 25 with confidence of 0.8477885127067566
# S$2.50 daily has_part
# create new relationship S$2.50 - has_part -> daily with confidence of 0.8593531847000122
# create new node with name as 27.8% and with type as PERCENT and sentiment with 0.0
# create new node with name as 27 April 2021 and with type as DATE and sentiment with 0.0
# create new relationship 27.8% - part_of -> daily with confidence of 0.9234201312065125
# daily 27.8% part_of
# create new relationship daily - part_of -> 27.8% with confidence of 0.8106085062026978
# create new relationship daily - has_part -> S$2.50 with confidence of 0.9164763689041138
# 27_April_2021 daily part_of
# create new relationship 27 April 2021 - part_of -> daily with confidence of 0.9565687775611877
# create new relationship S$2.50 - follows -> 27 April 2021 with confidence of 0.8117387294769287
# create new node with name as 25 June and with type as DATE and sentiment with 0.0
# create new node with name as 3% and with type as PERCENT and sentiment with 0.0
# create new node with name as p.a and with type as NORP and sentiment with 0.0
# create new node with name as the first working day and with type as DATE and sentiment with 0.0
# create new node with name as August and with type as DATE and sentiment with 0.0
# create new node with name as Bank and with type as ORG and sentiment with 0.0
# create new node with name as the following month and with type as DATE and sentiment with 0.0
# create new node with name as July and with type as DATE and sentiment with 0.0
# create new node with name as September and with type as DATE and sentiment with 0.0
# create new relationship 25 June - part_of -> Credit Card with confidence of 0.8993529677391052
# the_first_working_day 25 June follows
# create new relationship the first working day - follows -> 25 June with confidence of 0.8115957379341125
# August 25 June follows
# create new relationship August - follows -> 25 June with confidence of 0.8115957379341125
# Bank 25 June follows
# create new relationship Bank - follows -> 25 June with confidence of 0.8115957379341125
# the_following_month 25 June follows
# create new relationship the following month - follows -> 25 June with confidence of 0.8115957379341125
# July 25 June follows
# create new relationship July - follows -> 25 June with confidence of 0.8115957379341125
# September 25 June follows
# create new relationship September - follows -> 25 June with confidence of 0.8115957379341125
# create new relationship Credit Card - part_of -> 3% with confidence of 0.8966318964958191
# 3% Credit Card part_of
# create new relationship 3% - part_of -> Credit Card with confidence of 0.9488418102264404
# create new relationship Credit Card - part_of -> p.a with confidence of 0.87530118227005
# p.a Credit Card part_of
# create new relationship p.a - part_of -> Credit Card with confidence of 0.9251477718353271
# create new relationship Credit Card - part_of -> the first working day with confidence of 0.9330798387527466
# the_first_working_day Credit Card part_of
# create new relationship the first working day - part_of -> Credit Card with confidence of 0.9633850455284119
# create new relationship Credit Card - part_of -> August with confidence of 0.9330798387527466
# August Credit Card part_of
# create new relationship August - part_of -> Credit Card with confidence of 0.9633850455284119
# create new relationship Credit Card - part_of -> Bank with confidence of 0.9330798387527466
# Bank Credit Card part_of
# create new relationship Bank - part_of -> Credit Card with confidence of 0.9633850455284119
# create new relationship Credit Card - part_of -> the following month with confidence of 0.9330798387527466
# the_following_month Credit Card part_of
# create new relationship the following month - part_of -> Credit Card with confidence of 0.9633850455284119
# create new relationship Credit Card - part_of -> July with confidence of 0.9330798387527466
# July Credit Card part_of
# create new relationship July - part_of -> Credit Card with confidence of 0.9633850455284119
# create new relationship Credit Card - part_of -> September with confidence of 0.9330798387527466
# September Credit Card part_of
# create new relationship September - part_of -> Credit Card with confidence of 0.9633850455284119
# the_first_working_day 3% followed_by
# create new relationship the first working day - followed_by -> 3% with confidence of 0.8389431238174438
# August 3% followed_by
# create new relationship August - followed_by -> 3% with confidence of 0.8389431238174438
# Bank 3% followed_by
# create new relationship Bank - followed_by -> 3% with confidence of 0.8389431238174438
# the_following_month 3% followed_by
# create new relationship the following month - followed_by -> 3% with confidence of 0.8389431238174438
# July 3% followed_by
# create new relationship July - followed_by -> 3% with confidence of 0.8389431238174438
# September 3% followed_by
# create new relationship September - followed_by -> 3% with confidence of 0.8389431238174438
# create new node with name as the 1 month and with type as DATE and sentiment with 0.0
# create new node with name as October and with type as DATE and sentiment with 0.0
# create new relationship the 1 month - followed_by -> 1 month with confidence of 0.9743942618370056
# 1_month the 1 month followed_by
# create new relationship 1 month - followed_by -> the 1 month with confidence of 0.9360613226890564
# October 1 month followed_by
# create new relationship October - followed_by -> 1 month with confidence of 0.842919647693634
# create new node with name as full each month and with type as DATE and sentiment with 0.0
# create new node with name as each month and with type as DATE and sentiment with 0.0
# create new relationship full each month - followed_by -> each month with confidence of 0.9685067534446716
# each_month full each month followed_by
# create new relationship each month - followed_by -> full each month with confidence of 0.9126200079917908
# create new node with name as 1800 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 65 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 6 to 8 weeks and with type as DATE and sentiment with 0.0
# create new relationship 1800 - followed_by -> 65 with confidence of 0.9508926868438721
# 65 1800 followed_by
# create new relationship 65 - followed_by -> 1800 with confidence of 0.9119148254394531
# create new node with name as 24-hour and with type as TIME and sentiment with 0.0
# create new node with name as Customer Service Centre and with type as FAC and sentiment with 0.0
# create new relationship 24-hour - instance_of -> Customer Service Centre with confidence of 0.8026913404464722
# create new node with name as DBS Cards and with type as ORG and sentiment with 0.0
# create new node with name as Orchard Road and with type as FAC and sentiment with 0.0
# create new node with name as P.O. Box 360 and with type as FAC and sentiment with 0.0
# create new node with name as 912312 and with type as CARDINAL and sentiment with 0.0
# create new node with name as half and with type as CARDINAL and sentiment with 0.0
# create new relationship DBS Cards - headquarters_location -> Orchard Road with confidence of 0.9921161532402039
# Orchard_Road DBS Cards headquarters_location
# create new relationship Orchard Road - headquarters_location -> DBS Cards with confidence of 0.9895097017288208
# create new relationship DBS Cards - subsidiary -> P.O. Box 360 with confidence of 0.8724002242088318
# P.O._Box_360 DBS Cards subsidiary
# create new relationship P.O. Box 360 - subsidiary -> DBS Cards with confidence of 0.8932150602340698
# create new relationship DBS Cards - headquarters_location -> Singapore with confidence of 0.9301686882972717
# create new relationship DBS Cards - headquarters_location -> 912312 with confidence of 0.8192433714866638
# create new relationship DBS Cards - subsidiary -> half with confidence of 0.9059246778488159
# half DBS Cards subsidiary
# create new relationship half - subsidiary -> DBS Cards with confidence of 0.9149022698402405
# create new relationship DBS Cards - subsidiary -> monthly with confidence of 0.9059246778488159
# monthly DBS Cards subsidiary
# create new relationship monthly - subsidiary -> DBS Cards with confidence of 0.9149022698402405
# create new relationship Orchard Road - located_in_the_administrative_territorial_entity -> Singapore with confidence of 0.9499751925468445
# Singapore Orchard Road located_in_the_administrative_territorial_entity
# create new relationship Singapore - located_in_the_administrative_territorial_entity -> Orchard Road with confidence of 0.954057514667511
# create new relationship Orchard Road - located_in_the_administrative_territorial_entity -> 912312 with confidence of 0.8029608726501465
# 912312 Orchard Road located_in_the_administrative_territorial_entity
# create new relationship 912312 - located_in_the_administrative_territorial_entity -> Orchard Road with confidence of 0.8732746243476868
# create new relationship P.O. Box 360 - located_in_the_administrative_territorial_entity -> Singapore with confidence of 0.9436569213867188
# Singapore P.O. Box 360 located_in_the_administrative_territorial_entity
# create new relationship Singapore - located_in_the_administrative_territorial_entity -> P.O. Box 360 with confidence of 0.9202204346656799
# create new relationship P.O. Box 360 - part_of -> half with confidence of 0.8849115967750549
# half P.O. Box 360 part_of
# create new relationship half - part_of -> P.O. Box 360 with confidence of 0.9140729904174805
# create new relationship P.O. Box 360 - part_of -> monthly with confidence of 0.8849115967750549
# monthly P.O. Box 360 part_of
# create new relationship monthly - part_of -> P.O. Box 360 with confidence of 0.9140729904174805
# create new relationship Singapore - part_of -> 912312 with confidence of 0.8788182735443115
# 912312 Singapore part_of
# create new relationship 912312 - part_of -> Singapore with confidence of 0.9275113344192505
# create new node with name as 6327 2265 and with type as CARDINAL and sentiment with 0.0
# create new relationship 1800 - followed_by -> 65 with confidence of 0.9479461908340454
# 6327_2265 1800 follows
# create new relationship 6327 2265 - follows -> 1800 with confidence of 0.8540387153625488
# create new node with name as DBS/POSB Digibank and with type as ORG and sentiment with 0.0
# create new node with name as Mobile Banking and with type as ORG and sentiment with 0.0
# create new relationship DBS/POSB Digibank - developer -> href="https://www.dbs.com.sg with confidence of 0.9206638336181641
# href="https://www.dbs.com.sg DBS/POSB Digibank developer
# create new relationship href="https://www.dbs.com.sg - developer -> DBS/POSB Digibank with confidence of 0.8392268419265747
# create new relationship Mobile Banking - part_of -> href="https://www.dbs.com.sg with confidence of 0.830636739730835
# href="https://www.dbs.com.sg Mobile Banking part_of
# create new relationship href="https://www.dbs.com.sg - part_of -> Mobile Banking with confidence of 0.9257042407989502
# create new node with name as 8% and with type as PERCENT and sentiment with 0.0
# create new node with name as S$15.00 and with type as NORP and sentiment with 0.0
# create new node with name as Cash Advance and with type as ORG and sentiment with 0.0
# create new node with name as 28.5% and with type as PERCENT and sentiment with 0.0
# create new relationship 8% - has_part -> Cash Advance with confidence of 0.887680172920227
# Cash_Advance 8% has_part
# create new relationship Cash Advance - has_part -> 8% with confidence of 0.8406420946121216
# create new relationship 8% - followed_by -> 28.5% with confidence of 0.8004482984542847
# create new node with name as DBS/ POSB Balance Transfer and with type as ORG and sentiment with 0.0
# create new node with name as 0% and with type as PERCENT and sentiment with 0.0
# create new node with name as 6 or 12 months and with type as DATE and sentiment with 0.0
# create new relationship DBS/ POSB Balance Transfer - has_part -> 0% with confidence of 0.8272745609283447
# create new relationship DBS/ POSB Balance Transfer - follows -> 3 with confidence of 0.9241433143615723
# 3 DBS/ POSB Balance Transfer follows
# create new relationship 3 - follows -> DBS/ POSB Balance Transfer with confidence of 0.9174800515174866
# create new relationship 0% - has_part -> 6 or 12 months with confidence of 0.8475841283798218
# create new relationship 3 - follows -> href="https://www.dbs.com.sg with confidence of 0.9824601411819458
# href="https://www.dbs.com.sg 3 follows
# create new relationship href="https://www.dbs.com.sg - follows -> 3 with confidence of 0.9843375086784363
# create new node with name as EMV and with type as ORG and sentiment with 0.0
# create new node with name as Europay and with type as ORG and sentiment with 0.0
# create new node with name as MasterCard and with type as ORG and sentiment with 0.0
# create new node with name as Visa and with type as ORG and sentiment with 0.0
# create new relationship EMV - said_to_be_the_same_as -> Europay with confidence of 0.9963834285736084
# Europay EMV said_to_be_the_same_as
# create new relationship Europay - said_to_be_the_same_as -> EMV with confidence of 0.9956472516059875
# create new relationship EMV - said_to_be_the_same_as -> MasterCard with confidence of 0.953921914100647
# MasterCard EMV said_to_be_the_same_as
# create new relationship MasterCard - said_to_be_the_same_as -> EMV with confidence of 0.9482921957969666
# create new relationship EMV - said_to_be_the_same_as -> Visa with confidence of 0.9456604719161987
# Visa EMV said_to_be_the_same_as
# create new relationship Visa - said_to_be_the_same_as -> EMV with confidence of 0.9634796977043152
# create new relationship Europay - subsidiary -> MasterCard with confidence of 0.9087056517601013
# MasterCard Europay subsidiary
# create new relationship MasterCard - subsidiary -> Europay with confidence of 0.8143017292022705
# create new relationship Europay - subsidiary -> Visa with confidence of 0.8587913513183594
# create new relationship MasterCard - subsidiary -> Visa with confidence of 0.8870516419410706
# create new node with name as the EMV Chip Card and with type as EVENT and sentiment with 0.0
# ...
# create new relationship S$0.0388 - followed_by -> Sunday with confidence of 0.8108917474746704
# DBS_Point Sunday followed_by
# create new relationship DBS Point - followed_by -> Sunday with confidence of 0.8108917474746704
# href="https://www.dbs.com.sg Sunday followed_by
# create new relationship href="https://www.dbs.com.sg - followed_by -> Sunday with confidence of 0.8108917474746704
# create new node with name as Card Statements and with type as ORG and sentiment with 0.0
# create new relationship Card Statements - has_part -> href="https://www.dbs.com.sg with confidence of 0.9204323887825012
# href="https://www.dbs.com.sg Card Statements has_part
# create new relationship href="https://www.dbs.com.sg - has_part -> Card Statements with confidence of 0.9306463599205017
# create new node with name as ATM Card and with type as ORG and sentiment with 0.0
# href="https://www.dbs.com.sg DBS developer
# create new relationship href="https://www.dbs.com.sg - developer -> DBS with confidence of 0.8187897801399231
# create new node with name as Mobile and with type as GPE and sentiment with 0.0
# create new node with name as Visa Gold and with type as ORG and sentiment with 0.0
# create new node with name as Visa Platinum and with type as ORG and sentiment with 0.0
# create new node with name as 2 weeks and with type as DATE and sentiment with 0.0
# create new relationship Visa - followed_by -> Visa Gold with confidence of 0.9376882910728455
# create new relationship Visa - followed_by -> Visa Platinum with confidence of 0.948495090007782
# create new relationship Visa - follows -> 2 weeks with confidence of 0.960252583026886
# 2_weeks Visa follows
# create new relationship 2 weeks - follows -> Visa with confidence of 0.968775749206543
# create new relationship Visa Gold - followed_by -> Visa Platinum with confidence of 0.9872987866401672
# Visa_Platinum Visa Gold followed_by
# create new relationship Visa Platinum - followed_by -> Visa Gold with confidence of 0.977668285369873
# create new relationship Visa Platinum - followed_by -> 2 weeks with confidence of 0.9420592188835144
# 2_weeks Visa Platinum followed_by
# create new relationship 2 weeks - followed_by -> Visa Platinum with confidence of 0.9633200168609619
# create new node with name as NEFT and with type as ORG and sentiment with 0.0
# create new node with name as half-hourly and with type as TIME and sentiment with 0.0
# create new node with name as between 8 am to 4.30 pm and with type as TIME and sentiment with 0.0
# create new node with name as all working days and with type as DATE and sentiment with 0.0
# create new node with name as Saturdays and with type as DATE and sentiment with 0.0
# create new node with name as the same day and with type as DATE and sentiment with 0.0
# create new node with name as the next working day and with type as DATE and sentiment with 0.0
# create new node with name as at least three and with type as CARDINAL and sentiment with 0.0
# create new relationship NEFT - part_of -> half-hourly with confidence of 0.9198445677757263
# half-hourly NEFT part_of
# create new relationship half-hourly - part_of -> NEFT with confidence of 0.9325506091117859
# between_8_am_to_4.30_pm NEFT part_of
# create new relationship between 8 am to 4.30 pm - part_of -> NEFT with confidence of 0.8967857956886292
# create new relationship NEFT - part_of -> all working days with confidence of 0.9739091992378235
# all_working_days NEFT part_of
# create new relationship all working days - part_of -> NEFT with confidence of 0.962792158126831
# create new relationship half-hourly - part_of -> between 8 am to 4.30 pm with confidence of 0.8070828318595886
# all_working_days half-hourly has_part
# create new relationship all working days - has_part -> half-hourly with confidence of 0.8928235173225403
# the_same_day half-hourly has_part
# create new relationship the same day - has_part -> half-hourly with confidence of 0.8081007599830627
# create new relationship between 8 am to 4.30 pm - part_of -> all working days with confidence of 0.989860475063324
# all_working_days between 8 am to 4.30 pm part_of
# create new relationship all working days - part_of -> between 8 am to 4.30 pm with confidence of 0.9686828255653381
# the_next_working_day between 8 am to 4.30 pm location
# create new relationship the next working day - location -> between 8 am to 4.30 pm with confidence of 0.8118376731872559
# at_least_three between 8 am to 4.30 pm location
# create new relationship at least three - location -> between 8 am to 4.30 pm with confidence of 0.8118376731872559
# create new relationship all working days - has_part -> the same day with confidence of 0.8162183165550232
# the_same_day all working days has_part
# create new relationship the same day - has_part -> all working days with confidence of 0.9010825157165527
# create new relationship all working days - part_of -> the next working day with confidence of 0.908353865146637
# the_next_working_day all working days part_of
# create new relationship the next working day - part_of -> all working days with confidence of 0.9650444388389587
# create new relationship all working days - part_of -> at least three with confidence of 0.908353865146637
# at_least_three all working days part_of
# create new relationship at least three - part_of -> all working days with confidence of 0.9650444388389587
# create new relationship Saturdays - followed_by -> the same day with confidence of 0.8913074731826782
# the_same_day Saturdays followed_by
# create new relationship the same day - followed_by -> Saturdays with confidence of 0.9068785905838013
# create new relationship Saturdays - followed_by -> the next working day with confidence of 0.8012282252311707
# create new relationship Saturdays - followed_by -> at least three with confidence of 0.8012282252311707
# create new node with name as Rs 5 lakh and with type as MONEY and sentiment with 0.0
# create new node with name as max and with type as PERSON and sentiment with 0.0
# create new node with name as Cashline and with type as ORG and sentiment with 0.0
# create new node with name as MoneyLine and with type as ORG and sentiment with 0.0
# create new relationship Cashline - followed_by -> MoneyLine with confidence of 0.9864253997802734
# MoneyLine Cashline followed_by
# create new relationship MoneyLine - followed_by -> Cashline with confidence of 0.969420850276947
# create new node with name as below 95% and with type as PERCENT and sentiment with 0.0
# create new node with name as 2.1 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 5.1 and with type as CARDINAL and sentiment with 0.0
# create new node with name as 3.5 and with type as CARDINAL and sentiment with 0.0
# create new node with name as the Principal Cardholder and with type as ORG and sentiment with 0.0
# create new node with name as the Facilities or Electronic Service and with type as ORG and sentiment with 0.0
# create new relationship Bank - has_part -> 5.1 with confidence of 0.9518246650695801
# 5.1 Bank has_part
# create new relationship 5.1 - has_part -> Bank with confidence of 0.8962143063545227
# create new relationship Bank - has_part -> the Principal Cardholder with confidence of 0.818270742893219
# the_Principal_Cardholder Bank has_part
# create new relationship the Principal Cardholder - has_part -> Bank with confidence of 0.8163472414016724
# create new relationship Bank - has_part -> Cashline with confidence of 0.9626626968383789
# Cashline Bank has_part
# create new relationship Cashline - has_part -> Bank with confidence of 0.8856924176216125
# create new relationship Bank - has_part -> the Facilities or Electronic Service with confidence of 0.818270742893219
# the_Facilities_or_Electronic_Service Bank has_part
# create new relationship the Facilities or Electronic Service - has_part -> Bank with confidence of 0.8163472414016724
# create new relationship 2.1 - followed_by -> 5.1 with confidence of 0.9667105674743652
# 5.1 2.1 followed_by
# create new relationship 5.1 - followed_by -> 2.1 with confidence of 0.8887096047401428
# create new relationship 2.1 - followed_by -> 3.5 with confidence of 0.9841644167900085
# 3.5 2.1 followed_by
# create new relationship 3.5 - followed_by -> 2.1 with confidence of 0.9515349864959717
# create new relationship 2.1 - has_part -> Cashline with confidence of 0.8868291974067688
# Cashline 2.1 has_part
# create new relationship Cashline - has_part -> 2.1 with confidence of 0.9511043429374695
# create new relationship 5.1 - followed_by -> 3.5 with confidence of 0.9917057752609253
# 3.5 5.1 followed_by
# create new relationship 3.5 - followed_by -> 5.1 with confidence of 0.988493025302887
# create new relationship 5.1 - has_part -> Cashline with confidence of 0.9588193893432617
# Cashline 5.1 has_part
# create new relationship Cashline - has_part -> 5.1 with confidence of 0.9711307287216187
# create new relationship 3.5 - followed_by -> the Principal Cardholder with confidence of 0.9685170650482178
# the_Principal_Cardholder 3.5 followed_by
# create new relationship the Principal Cardholder - followed_by -> 3.5 with confidence of 0.9748960137367249
# create new relationship 3.5 - followed_by -> the Facilities or Electronic Service with confidence of 0.9685170650482178
# the_Facilities_or_Electronic_Service 3.5 followed_by
# create new relationship the Facilities or Electronic Service - followed_by -> 3.5 with confidence of 0.9748960137367249
# create new relationship the Principal Cardholder - has_part -> Cashline with confidence of 0.969200074672699
# Cashline the Principal Cardholder has_part
# create new relationship Cashline - has_part -> the Principal Cardholder with confidence of 0.9610396027565002
# create new relationship Cashline - has_part -> the Facilities or Electronic Service with confidence of 0.9610396027565002
# the_Facilities_or_Electronic_Service Cashline has_part
# create new relationship the Facilities or Electronic Service - has_part -> Cashline with confidence of 0.969200074672699
# create new node with name as Instalment Plans/Balance Transfers and with type as ORG and sentiment with 0.0
# create new node with name as DBS Debit Card and with type as ORG and sentiment with 0.0
# create new node with name as ₹150+ and with type as MONEY and sentiment with 0.0
# create new node with name as 18% and with type as PERCENT and sentiment with 0.0
# create new node with name as the second year and with type as DATE and sentiment with 0.0
# create new node with name as ₹150+₹27 and with type as MONEY and sentiment with 0.0
# create new node with name as first and with type as ORDINAL and sentiment with 0.0
# create new node with name as July 2020 and with type as DATE and sentiment with 0.0
# create new node with name as the month of June 2020 and with type as DATE and sentiment with 0.0
# create new relationship annual - follows -> July 2020 with confidence of 0.8232366442680359
# create new relationship ₹150+ - followed_by -> ₹150+₹27 with confidence of 0.9074824452400208
# ₹150+₹27 ₹150+ followed_by
# create new relationship ₹150+₹27 - followed_by -> ₹150+ with confidence of 0.9133139848709106
# create new relationship ₹150+ - followed_by -> first with confidence of 0.959620475769043
# first ₹150+ followed_by
# create new relationship first - followed_by -> ₹150+ with confidence of 0.9459831714630127
# create new relationship 18% - follows -> July 2020 with confidence of 0.8401802778244019
# July_2020 18% follows
# create new relationship July 2020 - follows -> 18% with confidence of 0.8561906218528748
# create new relationship the second year - followed_by -> first with confidence of 0.9176457524299622
# create new relationship the second year - has_part -> the month of June 2020 with confidence of 0.8748599886894226
# the_month_of_June_2020 the second year has_part
# create new relationship the month of June 2020 - has_part -> the second year with confidence of 0.8823169469833374
# create new relationship ₹150+₹27 - followed_by -> first with confidence of 0.8879770040512085
# first ₹150+₹27 followed_by
# create new relationship first - followed_by -> ₹150+₹27 with confidence of 0.8282853364944458
# create new relationship ₹150+₹27 - follows -> July 2020 with confidence of 0.886552095413208
# July_2020 ₹150+₹27 follows
# create new relationship July 2020 - follows -> ₹150+₹27 with confidence of 0.8943490982055664
# create new relationship first - followed_by -> the month of June 2020 with confidence of 0.9563534259796143
# the_month_of_June_2020 first followed_by
# create new relationship the month of June 2020 - followed_by -> first with confidence of 0.946929395198822
# create new relationship July 2020 - follows -> the month of June 2020 with confidence of 0.8750483393669128
# the_month_of_June_2020 July 2020 follows
# create new relationship the month of June 2020 - follows -> July 2020 with confidence of 0.8218408226966858
# create new node with name as 27 and with type as MONEY and sentiment with 0.0
# create new node with name as 177 and with type as MONEY and sentiment with 0.0
# create new node with name as 150+GST and with type as MONEY and sentiment with 0.0
# create new node with name as this year and with type as DATE and sentiment with 0.0
# create new relationship 150+GST - follows -> this year with confidence of 0.8746638298034668
# this_year 150+GST follows
# create new relationship this year - follows -> 150+GST with confidence of 0.8935506343841553
# create new relationship annual - followed_by -> this year with confidence of 0.9282796382904053
# this_year annual followed_by
# create new relationship this year - followed_by -> annual with confidence of 0.9409143328666687
# create new relationship 150+GST - follows -> this year with confidence of 0.8491032719612122
# this_year 150+GST follows
# create new relationship this year - follows -> 150+GST with confidence of 0.8701411485671997
# create new relationship the second year - followed_by -> this year with confidence of 0.9191649556159973
# this_year the second year followed_by
# create new relationship this year - followed_by -> the second year with confidence of 0.8249390721321106
# create new node with name as 4 and with type as CARDINAL and sentiment with 0.0
# create new node with name as that year and with type as DATE and sentiment with 0.0
# create new relationship annual - follows -> 4 with confidence of 0.8168418407440186
# create new relationship 4 - follows -> that year with confidence of 0.9045310020446777
# that_year 4 follows
# create new relationship that year - follows -> 4 with confidence of 0.8773844838142395
# create new relationship 4 - follows -> that year with confidence of 0.8892529010772705
# that_year 4 follows
# create new relationship that year - follows -> 4 with confidence of 0.8769173622131348
# create new node with name as Debit Card and with type as ORG and sentiment with 0.0
# create new node with name as 2 million ATMs and with type as QUANTITY and sentiment with 0.0
# create new relationship Debit Card - part_of -> 2 million ATMs with confidence of 0.9898183941841125
# 2_million_ATMs Debit Card part_of
# create new relationship 2 million ATMs - part_of -> Debit Card with confidence of 0.9888796806335449
# create new relationship 2 million ATMs - part_of -> 177 with confidence of 0.8643143177032471
# 177 2 million ATMs part_of
# create new relationship 177 - part_of -> 2 million ATMs with confidence of 0.9323571920394897
# create new node with name as India and with type as GPE and sentiment with 0.0
# create new node with name as nearly 2,00,000 ATMs and with type as QUANTITY and sentiment with 0.0
# create new node with name as Visa Tap to Pay and with type as ORG and sentiment with 0.0
# create new node with name as Point and with type as ORG and sentiment with 0.0
# create new node with name as up to INR 2,000 and with type as MONEY and sentiment with 0.0
# create new node with name as PoS and with type as ORG and sentiment with 0.0
# PoS Point has_part
# create new relationship PoS - has_part -> Point with confidence of 0.8197041749954224
# create new relationship up to INR 2,000 - has_part -> PoS with confidence of 0.9767981767654419
# PoS up to INR 2,000 has_part
# create new relationship PoS - has_part -> up to INR 2,000 with confidence of 0.989628791809082

# %%
query = (
        "MATCH (f)-[:HAS_SUBSECTION]->(SubSection {name:'DBS Online Rewards'}) RETURN f.Question AS Question, f.Answer AS Answer "
)

# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    for result in results:
        print('Question' + ': '+result['Question'])
        print('Answer' + ': '+result['Answer'])
# Out:
# Question: What is DBS Online Rewards?
# Answer: DBS Online rewards website allows you to check your DBS points and redeem rewards online.
# Question: How do I login to redeem?
# Answer: Simply enter your digibank user ID and PIN to login.
#
# For Daily$ rebates, please login to <a href="https://internet-banking.dbs.com.sg/">DBS iBanking</a>  to redeem your Daily$ rebates
# Question: I am not an existing DBS iBanking customer; can I still redeem my points online?
# Answer: No. You will need to register for a digibank user ID to perform DBS rewards redemption. Click <a href="https://internet-banking.dbs.com.sg/ibAPL/Welcome" >here</a>  to register now.
#
# Question: I am not a DBS Cardmember, can I still access the DBS Online Rewards website?
# Answer: Yes. You can still browse the website to gather information. However, you need to be a DBS credit cardmember and digibank user to login. To sign up for a DBS credit card, please visit <a href="https://www.dbs.com.sg/personal/cards/default.page" >www.dbs.com/sg/cards</a>.
# Question: I have more than one DBS Credit Card. How can I redeem my DBS Points on this rewards site?
# Answer: You can login with your digibank user ID and PIN. All DBS points accumulated via all your eligible credit cards will be automatically consolidated to your account.
# Question: Can I change the billing address displayed in my account?
# Answer: No. For security reasons, change of billing address is not permitted via this site. You may update your address via DBS/POSB iBanking or DBS/POSB digibank app. Refer to update profile steps <a href="https://www.dbs.com.sg/personal/support/general-product.html" >here</a>.
# Question: Are all my DBS Credit Cards eligible for redemption on this website?
# Answer: All DBS reward point-earning credit cards are eligible for the redemption programme. DBS Corporate Liability Card, DBS Purchasing Card, Country Club Corporate Card, DBS Live Fresh Card, DBS Saab Credit Card, DBS Takashimaya Card, DBS Esso Card, DBS yuu Card, SAFRA DBS Credit/Debit Card, POSB Credit Card and all DBS and POSB Debit Cards are not eligible for this DBS points reward redemption program.
# Question: How can I view my DBS Points and expiry date?
# Answer: After login, please click on "My DBS Points Details" and all your DBS Points will be displayed with the respective expiry dates.
# Question: How do I search for rewards?
# Answer: Please use the search bar below the menu. You can search for products by the following ways:
#
# Points range - drag the number
# Enter a keyword into the text box
# Select any one of the category on the menu bar
# Question: How do I redeem for items?
# Answer: Drag and drop the item into the shopping cart on the right, you may increase or decrease quantity by clicking on the + or - sign.
# Click on the product and a light box will open up, enter desired quantity and click "Add to cart"
# Question: How do I delete an item from the shopping cart?
# Answer: Click on the - (minus) sign until it is removed from the shopping cart
# Go to "View shopping cart" and click on "Remove" to delete item
# Question: If I spend on my credit card now, how long does it take for me to be able to redeem on the points?
# Answer: Your credit card points will be updated once the merchant has posted the transaction(s) and it will be reflected in your account within 24 hours.
#
# Please note that DBS shall have the discretion to postpone the awarding of credit card points for a reasonable period in the event of unforeseen circumstances, including any delay arising from system issues.

# %%
query = (
        "MATCH (f {Question:'What is DBS Online Rewards?'}) RETURN f.Question AS Question, f.Answer AS Answer "
)

# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    for result in results:
        print('Question' + ': '+result['Question'])
        print('Answer' + ': '+result['Answer'])
# Out:
# Question: What is DBS Online Rewards?
# Answer: DBS Online rewards website allows you to check your DBS points and redeem rewards online.

# %%
query = (
        "MATCH (ss)-[:SUBSECTION_OF]->(Section {name:'Bank Cards'}) RETURN ss.name AS SubSection"
)

# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    for result in results:
        print('SubSection' + ': '+result['SubSection'])
# Out:
# SubSection: Applying for a DBS Debit Card or Credit Card
# SubSection: DBS Reward Points / DBS Online Rewards
# SubSection: DBS Online Rewards
# SubSection: Paying Your Credit Card Balance
# SubSection: Charge Disputes
# SubSection: Cancelling and Replacing Cards, Changing Your PIN
# SubSection: Upgrading or Changing Cards
# SubSection: Cash Advance and Funds Transfer
# SubSection: Enhancing Card Usage Security
# SubSection: Card Activation
# SubSection: Credit Card
# SubSection: Credit Card
# SubSection: Cancel Card
# SubSection: Card Upgrade
# SubSection: Overlimit Suspension

# %%
query = (
        #"MATCH (ORG)-[:instance_of]->(ORG {name: 'DBS Credit/Debit Card'}) RETURN ORG.name AS name"
        "MATCH p=()-[:instance_of]->(ORG {name: 'DBS Credit/Debit Card'}) RETURN ORG.name AS name"
)

# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    for result in results:
        print('Name' + ': '+result['name'])
# Out:
# Name: DBS Credit/Debit Card
# Name: DBS Credit/Debit Card
# Name: DBS Credit/Debit Card

# %%
query = (
    "MATCH p=()-[:PART_OF]->(FAQ {Id : 1}) RETURN p LIMIT 25;"
)

# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    print(results)
    for result in results:
        print(result['p'])
# Out:
# <neo4j._sync.work.result.Result object at 0x19d405c10>
# <Path start=<Node element_id='4:5e2359e9-89fa-457b-b603-d6efe892f544:42' labels=frozenset({'Question'}) properties={'Label': 'Am I eligible for a debit card?'}> end=<Node element_id='4:5e2359e9-89fa-457b-b603-d6efe892f544:41' labels=frozenset({'FAQ'}) properties={'Answer': 'You must be at least 16 years old and have a POSB Savings Account, DBS Savings Plus Account, DBS Autosave Account or DBS Current Account. To open one of these accounts, click <a href="https://www.dbs.com.sg/personal/deposits/bank-with-ease/addon-casa" >here</a>\n\nIf you are a foreigner, please apply for a debit card at any of our branches. You will need to present your passport and an employment pass that is valid for at least 6 months.', 'Label': 'eligible_debit_card', 'Question': 'Am I eligible for a debit card?', 'Id': 1}> size=1>
# <Path start=<Node element_id='4:5e2359e9-89fa-457b-b603-d6efe892f544:399' labels=frozenset({'Answer'}) properties={'Label': 'You must be at least 16 years old and have a POSB Savings Account, DBS Savings Plus Account, DBS Autosave Account or DBS Current Account. To open one of these accounts, click <a href="https://www.dbs.com.sg/personal/deposits/bank-with-ease/addon-casa" >here</a>\n\nIf you are a foreigner, please apply for a debit card at any of our branches. You will need to present your passport and an employment pass that is valid for at least 6 months.'}> end=<Node element_id='4:5e2359e9-89fa-457b-b603-d6efe892f544:41' labels=frozenset({'FAQ'}) properties={'Answer': 'You must be at least 16 years old and have a POSB Savings Account, DBS Savings Plus Account, DBS Autosave Account or DBS Current Account. To open one of these accounts, click <a href="https://www.dbs.com.sg/personal/deposits/bank-with-ease/addon-casa" >here</a>\n\nIf you are a foreigner, please apply for a debit card at any of our branches. You will need to present your passport and an employment pass that is valid for at least 6 months.', 'Label': 'eligible_debit_card', 'Question': 'Am I eligible for a debit card?', 'Id': 1}> size=1>

# %%
results

# %%
query = (
    """MATCH p=(e:Entity)-[:MENTIONS]->(f:FAQ) 
    WHERE (toLower(e.name)='platinum') 
    RETURN f.Label AS Label, f.Question AS Question, f.Answer AS Answer LIMIT 25;"""
)
# Execuate above query to modify neo4j db:
with graph.session() as session:
    results = session.run(query)
    for result in results:
        print("Label: " + result['Label'])
        print("Question: " + result['Question'])
        print("Answer: " + result['Answer'])
# Out:
# Label: eligible_credit_card
# Question: Am I eligible for a credit card?
# Answer: If you're Singaporean or have permanent residency and you're over 21 years of age, you can apply for a DBS <a href="https://www.dbs.com.sg/personal/cards/credit-cards/default.page"> Credit Card </a>. You'll need to earn at least S$30,000 a year. For some cards, especially Platinum cards, you'll need to earn more so check the Application Details for the card you're interested in.
#
# If you're a foreigner with a valid employment pass, you'll need to earn a least S$45,000 a year unless otherwise stated.
